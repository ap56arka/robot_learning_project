# %%
import os
import cv2
import numpy as np
from PIL import Image
import glob

## For gemini Qwerying
from google import genai
from google.genai import types
from PIL import Image
import io
import time

## for path planning
import numpy as np
import heapq
import matplotlib.pyplot as plt
import json
from scipy import ndimage

# %%
def extract_frames(video_path, output_folder):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Load the video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"❌ Error: Cannot open video file {video_path}")
        return

    frame_count = 0
    print(f"🎥 Extracting frames from: {video_path}")

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video

        # Save frame as image file
        frame_filename = os.path.join(output_folder, f"frame_{frame_count:05d}.jpg")
        cv2.imwrite(frame_filename, frame)
        frame_count += 1

    cap.release()
    print(f"✅ Done! {frame_count} frames saved in: {output_folder}")


# ====== EDIT THESE PATHS ======
original_video_path = "rpl_staircase_original.mp4"
masked_video_path = "rpl_staircase_masked.mp4"

original_frames_folder = "rpl_staircase_original_frames"
masked_frames_folder = "rpl_staircase_masked_frames"

# ====== RUN EXTRACTION ======
extract_frames(original_video_path,original_frames_folder)
extract_frames(masked_video_path, masked_frames_folder)
# Out:
# 🎥 Extracting frames from: rpl_staircase_original.mp4
# ✅ Done! 681 frames saved in: rpl_staircase_original_frames
# 🎥 Extracting frames from: rpl_staircase_masked.mp4
# ✅ Done! 681 frames saved in: rpl_staircase_masked_frames

# %%
def query_gemini_with_premade_masks(original_image, masked_image, client):
    """
    Query Gemini API with pre-existing original and masked images
    """
#     prompt = """You will see TWO images:

# IMAGE 1 (Left): The original real-world scene
# IMAGE 2 (Right): A segmented version where each colored region represents a distinct area, with numbers identifying each region. Black areas are unsegmented background - ignore them.

# ANALYSIS INSTRUCTIONS:
# 1. Focus ONLY on the numbered colored regions in IMAGE 2
# 2. For each numbered region, examine the corresponding area in IMAGE 1 to understand what terrain/objects are present
# 3. Assign a continuous traversability score from 0.0 to 1.0 for a boston dynamic spot robot:

# Assess how easily a boston dynamic spot robot could navigate each region. 
# Consider that real environments often have mixed characteristics - an area might contain both traversable surfaces and obstacles. 
# Balance these factors to determine an overall score. Be resonable about choosing those no.s

# Black coloured region is unsegmented areas which is mostly not traversable area. Only analyze the numbered colored regions.

# 1. **Traversability Score (0.0-1.0)** — 0.0 means not traversable (e.g., cars, trees, walls, people, or obstacles). 
#    1.0 means fully traversable for a boston dynamic spot  robot (e.g., flat roads, walkable pavement).
# 2. **Confidence Score (0.0-1.0)** — how confident you are in the score.

# Please output **only** in the following format (no extra text, no explanations):

# region no. : <Traversability Score>, <Confidence Score>, <very short reason>

# Example:
# Region 1: 0.0, 0.95
# Region 2: 0.8, 0.9
# Region 3: 0.3, 0.7
# ..."""

    prompt = """You will see TWO images:

IMAGE 1 (Left): The original real-world scene - USE THIS TO UNDERSTAND WHAT'S IN EACH REGION
IMAGE 2 (Right): A segmented version with numbered colored regions - USE THIS TO IDENTIFY REGION BOUNDARIES

CRITICAL ANALYSIS PROCESS:
1. Look at IMAGE 2 to identify numbered region boundaries along with its associated colour.
2. For EACH numbered region, CAREFULLY EXAMINE the corresponding area in IMAGE 1 to understand:
   - What objects/terrain are present (roads, grass, walls, vehicles, stairs, slopy area etc.)
   - Surface type and quality
   - Obstacle density and navigability
3.  reason about traversability based on IMAGE 1 content
4. Assign scores accordingly
Assess how easily a high torque motored wheel robot could navigate each region, this robot can go to the slopy region but not on the walls or stairs. Don't consider the slopy region as a wall 
Consider that real environments often have mixed characteristics - an area might contain both traversable surfaces and obstacles. 
Balance these factors to determine an overall score. Be resonable about choosing those no.s

Black coloured region is unsegmented areas which is mostly not traversable area. Only analyze the numbered colored regions.

1. **Traversability Score (0.0-1.0)** — 0.0 means not traversable (e.g., cars, trees, walls, people, or obstacles). in between may be for slopy regions 
    1.0 means fully traversable for a high torque motored wheel robot (e.g., flat roads, walkable pavement).
2. **Confidence Score (0.0-1.0)** — how confident you are in the score.


Please output **only** in the following format (no extra text, no explanations):

region no. : <Traversability Score>, <Confidence Score> <very short reason>

Example:
Region 0: 0.0, 0.95, reason
Region 1: 0.8, 0.9, reason
Region 2: 0.3, 0.7, reason
..."""

    model_name = "gemini-flash-lite-latest"
    print(f"Sending request to model: {model_name}...")

    start_time = time.time()

    try:
        # Send both pre-made images to Gemini
        response = client.models.generate_content(
            model=model_name,
            contents=[prompt, original_image, masked_image],
            config=types.GenerateContentConfig(
                temperature=0.1
            )
        )

        end_time = time.time()
        duration = end_time - start_time
        
        print(f"\n✅ API Call Completed.")
        print(f"⏱️ Time Taken: {duration:.2f} seconds")
        print("----------------------------------------\n")

        raw_output = response.text
        print("\n--- Raw Gemini Output ---")
        print(raw_output)
        print("-------------------------\n")

        # Parse the output
        region_scores = {}
        for line in raw_output.strip().split('\n'):
            line = line.strip()
            if line.startswith('Region') and ':' in line:
                try:
                    parts = line.split(':')
                    region_id = parts[0].strip()
                    # print(region_id)
                    scores_part = parts[1].strip()
                    score_parts = scores_part.split(',')
                    if len(score_parts) >= 2:
                        # Take first two parts and strip any extra text/whitespace
                        score_str = score_parts[0].strip()
                        confidence_str = score_parts[1].strip()
                        
                        # Extract only numbers from confidence string (in case there's text after)
                        confidence_str = ''.join(c for c in confidence_str if c.isdigit() or c == '.')
                        
                        traversability = float(score_str)
                        confidence = float(confidence_str) if confidence_str else 1.0
                    else:
                        # Fallback if only one score is provided
                        traversability = float(scores_part.strip())
                        confidence = 1.0
                    
                    region_scores[region_id] = {
                        'traversability': traversability,
                        'confidence': confidence
                    }
                    
                    print(f"✅ Parsed: {region_id} -> T={traversability:.2f}, C={confidence:.2f}")
                    
                    region_scores[region_id] = {
                        'traversability': traversability,
                        'confidence': confidence
                    }
                except ValueError:
                    print(f"Warning: Could not parse line: {line}")
                    continue

        print("--- Successfully Parsed Scores ---")
        for region, scores in region_scores.items():
            print(f"{region}: Traversability={scores['traversability']:.2f}, Confidence={scores['confidence']:.2f}")
            
        return region_scores

    except Exception as e:
        end_time = time.time()
        duration = end_time - start_time
        print(f"❌ An error occurred after {duration:.2f} seconds: {e}")
        return None

# %%
def unified_a_star_planning(costmap, start, goal=None, horizon_distance=None):
    """
    Unified A* planning that uses the working horizon logic and correct goal-based logic
    """
    height, width = costmap.shape
    
    # Validate inputs
    if goal is not None and horizon_distance is not None:
        raise ValueError("Cannot specify both goal and horizon_distance. Choose one planning mode.")
    if goal is None and horizon_distance is None:
        raise ValueError("Must specify either goal or horizon_distance.")
    
    planning_type = 'goal' if goal is not None else 'horizon'
    
    # Define movements (8-connected for smoother paths)
    movements = [
        (-1, 0), (1, 0), (0, -1), (0, 1),      # 4-connected
        (-1, -1), (-1, 1), (1, -1), (1, 1)     # Diagonal
    ]
    diagonal_cost = np.sqrt(2)
    
    # Priority queue: (f_score, g_score, position, parent)
    open_set = []
    heapq.heappush(open_set, (0, 0, start, None))
    
    # Tracking dictionaries
    g_score = {start: 0}
    f_score = {start: 0}
    came_from = {}
    closed_set = set()
    
    current_pos = start
    reached_horizon = False
    success = False
    
    while open_set and not (success and planning_type == 'goal'):
        # Get node with lowest f_score
        current_f, current_g, current_pos, parent = heapq.heappop(open_set)
        
        if current_pos in closed_set:
            continue
            
        came_from[current_pos] = parent
        closed_set.add(current_pos)
        
        # Check if target is reached - USE WORKING HORIZON LOGIC
        if planning_type == 'goal':
            if current_pos == goal:
                success = True
                break
        else:  # horizon-based - USE YOUR WORKING LOGIC
            distance_from_start = np.sqrt((current_pos[0] - start[0])**2 + 
                                        (current_pos[1] - start[1])**2)
            if distance_from_start >= horizon_distance:
                reached_horizon = True
                success = True
                break
        
        # Explore neighbors - USE YOUR WORKING LOGIC
        for move in movements:
            neighbor = (current_pos[0] + move[0], current_pos[1] + move[1])
            
            # Check bounds
            if (0 <= neighbor[0] < height and 0 <= neighbor[1] < width):
                # Skip if obstacle (very high cost) - USE YOUR WORKING THRESHOLD
                if costmap[neighbor[0], neighbor[1]] > 0.9:
                    continue
                
                # Calculate movement cost - USE YOUR WORKING LOGIC
                move_cost = diagonal_cost if abs(move[0]) + abs(move[1]) == 1 else 1.0
                base_cost = costmap[neighbor[0], neighbor[1]]
                
                ## ADD THIS LINE FOR UP PREFERENCE:
                if move == (-1, 0):  # If moving up
                    move_cost *= 0.1  # Reduce cost by 70% for upward movement
                if move == (-1, 1) or move == (-1, -1) :  # If moving  diagonal up
                    move_cost *= 0.25 
                if move == (0, 1) or move == (0, -1) :  # If moving right and left
                    move_cost *= 0.5  

                # Total cost to reach neighbor - USE YOUR WORKING LOGIC
                tentative_g = current_g + move_cost * base_cost
                
                if neighbor not in g_score or tentative_g < g_score[neighbor]:
                    
                    g_score[neighbor] = tentative_g
                    f_score[neighbor] = tentative_g 
                    heapq.heappush(open_set, (f_score[neighbor], tentative_g, neighbor, current_pos))
    
    # Reconstruct path - USE YOUR WORKING LOGIC
    path = []
    if planning_type == 'goal':
        if success:
            while current_pos is not None:
                path.append(current_pos)
                current_pos = came_from.get(current_pos)
            path.reverse()
    else:  # horizon-based - USE YOUR WORKING LOGIC
        if reached_horizon or current_pos != start:
            while current_pos is not None:
                path.append(current_pos)
                current_pos = came_from.get(current_pos)
            path.reverse()
    
    return path, success, planning_type

# %%
def create_costmap_from_mask_and_scores(mask_dict, region_scores):
    """
    Create costmap directly from boolean masks and region scores
    
    Args:
        mask_dict: Dictionary with region IDs as keys and boolean masks as values
        region_scores: Dictionary with region IDs as keys and combined scores as values
    
    Returns:
        cost_map: Costmap where each pixel has the score of its dominant region
    """
    if not mask_dict:
        raise ValueError("mask_dict is empty")
    
    # Assume all masks are same shape, get first mask's shape
    sample_mask = next(iter(mask_dict.values()))
    H, W = sample_mask.shape
    
    # Initialize costmap with default high cost (for unknown/uncovered areas)
    cost_map = np.ones((H, W), dtype=np.float32)
    
    # Sort masks by area descending (largest regions processed first)
    masks_sorted = sorted(mask_dict.items(), key=lambda x: np.sum(x[1]), reverse=True)
    
    print(f"📊 Processing {len(masks_sorted)} masks for costmap creation")
    
    for obj_id, mask in masks_sorted:
        # Check if this region has scores from VLM
        if obj_id in region_scores:
            # Get the traversability score for this region
            score = region_scores[obj_id].get('traversability')
            print(f"score: {score}")
            
            # Convert score to cost (higher score = lower cost)
            cost_value = 1.0 - score
            
            # Assign cost to pixels where mask is True
            cost_map[mask] = cost_value
        else:
            # Leave it as default high cost (1.0) if no region scores
            print(f"  ⚠️  {obj_id}: No region scores found, using default cost 1.0")
            # Don't assign anything - cost_map already has default 1.0
        
        print(f"  🎯 {obj_id}: score={score:.3f}, cost={cost_value:.3f}, area={np.sum(mask)} pixels")
    
    return cost_map

# %%
def create_costmap_from_mask_and_scores(mask_dict, region_scores, gradient_threshold=0.6):
    """
    Create gradient-based costmap from boolean masks and region scores
    """
    if not mask_dict:
        raise ValueError("mask_dict is empty")
    
    # Assume all masks are same shape, get first mask's shape
    sample_mask = next(iter(mask_dict.values()))
    H, W = sample_mask.shape
    
    # Initialize costmap with default high cost (for unknown/uncovered areas)
    cost_map = np.ones((H, W), dtype=np.float32)
    
    print(f"📊 Processing {len(mask_dict)} masks for gradient-based costmap")
    
    # Apply gradient costs for high-traversability regions
    for region_id, mask in mask_dict.items():
        # Check if this region has scores from VLM
        if region_id in region_scores:
            # Get the traversability score for this region
            traversability = region_scores[region_id].get('traversability')
            base_cost = 1.0 - traversability
            
            # Apply gradient cost for high-traversability regions
            if traversability >= gradient_threshold:
                # Compute distance transform from region boundaries
                from scipy import ndimage
                
                # Get boundaries (edges of the mask)
                structure = np.ones((3, 3))  # 8-connected
                eroded = ndimage.binary_erosion(mask, structure)
                boundaries = mask & ~eroded
                
                # Distance transform from boundaries
                distance_from_boundary = ndimage.distance_transform_edt(~boundaries)
                
                # Normalize to 0-1 range within the region
                max_dist = np.max(distance_from_boundary[mask])
                if max_dist > 0:
                    normalized_distance = distance_from_boundary / max_dist
                    
                    # Adjust cost: lower in center, higher near boundaries
                    gradient_adjustment = 0.1 * (1 - normalized_distance)  # 0 at center, 0.1 at boundary
                    adjusted_cost = base_cost + gradient_adjustment
                    
                    # Apply only within the mask region
                    cost_map[mask] = adjusted_cost[mask]
                else:
                    cost_map[mask] = base_cost
            else:
                cost_map[mask] = base_cost
            
            print(f"  🎯 {region_id}: traversability={traversability:.3f}, base_cost={base_cost:.3f}, area={np.sum(mask)} pixels")
        else:
            print(f"  ⚠️  {region_id}: No region scores found, using default cost 1.0")
    
    return cost_map

# %%
def create_costmap_from_mask_and_scores(mask_dict, region_scores, gradient_threshold=0.5):
    """
    Create gradient-based costmap from boolean masks and region scores
    """
    if not mask_dict:
        raise ValueError("mask_dict is empty")
    
    # Assume all masks are same shape, get first mask's shape
    sample_mask = next(iter(mask_dict.values()))
    H, W = sample_mask.shape
    
    # Initialize costmap with default high cost (for unknown/uncovered areas)
    cost_map = np.ones((H, W), dtype=np.float32)
    
    print(f"📊 Processing {len(mask_dict)} masks for gradient-based costmap")
    
    # Apply gradient costs for high-traversability regions
    for region_id, mask in mask_dict.items():
        # Check if this region has scores from VLM
        if region_id in region_scores:
            # Get the traversability score for this region
            traversability = region_scores[region_id].get('traversability')
            base_cost = 1.0 - traversability
            
            # Apply gradient cost for high-traversability regions
            if traversability >= gradient_threshold:
                # Compute distance transform from region boundaries
                from scipy import ndimage
                
                # CORRECTED: Get boundaries (edges of the mask)
                structure = np.ones((3, 3))  # 8-connected
                eroded = ndimage.binary_erosion(mask, structure)
                boundaries = mask & ~eroded
                
                # CORRECTED: Distance transform FROM boundaries INSIDE the mask
                # Create a mask where boundaries are 0 (source) and interior is 1 (target)
                distance_mask = mask.astype(np.uint8)
                distance_mask[boundaries] = 0  # Set boundaries as source points
                
                # Calculate distance from boundaries to interior
                distance_from_boundary = ndimage.distance_transform_edt(distance_mask)
                
                # Normalize to 0-1 range within the region (excluding boundaries)
                interior_mask = mask & ~boundaries
                if np.any(interior_mask):
                    max_dist = np.max(distance_from_boundary[interior_mask])
                    if max_dist > 0:
                        normalized_distance = distance_from_boundary / max_dist
                        
                        # Adjust cost: lower in center, higher near boundaries
                        gradient_adjustment = 0.1 * (1 - normalized_distance)  # 0 at center, 0.1 at boundary
                        adjusted_cost = base_cost + gradient_adjustment
                        
                        # Apply only within the mask region
                        cost_map[mask] = adjusted_cost[mask]
                    else:
                        cost_map[mask] = base_cost
                else:
                    cost_map[mask] = base_cost
            else:
                cost_map[mask] = base_cost
            
            print(f"  🎯 {region_id}: traversability={traversability:.3f}, base_cost={base_cost:.3f}, area={np.sum(mask)} pixels")
        else:
            print(f"  ⚠️  {region_id}: No region scores found, using default cost 1.0")
    
    return cost_map

# %%
def process_video_frames(original_frames_dir, segmented_frames_dir, npz_base_dir,
                        output_costmap_dir, output_overlay_dir, client,
                        depth_scores_path,  # New parameter for depth scores JSON
                        keyframe_interval=50, horizon_distance=20, 
                        planning_mode='horizon', goal_point=None,
                        traversability_weight=0.7, depth_weight=0.3):
    """
    Process video frames with VLM querying at keyframes and path planning for every frame
    Uses segmented images for VLM and NPZ masks for costmap creation
    """
    # Get sorted list of frames from both directories
    original_frames = sorted(glob.glob(os.path.join(original_frames_dir, "*.png"))) + \
                     sorted(glob.glob(os.path.join(original_frames_dir, "*.jpg")))
    segmented_frames = sorted(glob.glob(os.path.join(segmented_frames_dir, "*.png"))) + \
                       sorted(glob.glob(os.path.join(segmented_frames_dir, "*.jpg")))
    
    # Ensure same number of frames
    min_frames = min(len(original_frames), len(segmented_frames))
    original_frames = original_frames[:min_frames]
    segmented_frames = segmented_frames[:min_frames]
    
    # Load depth scores from JSON file
    # try:
    #     with open(depth_scores_path, 'r') as f:
    #         depth_scores_data = json.load(f)
    #     print(f"📊 Loaded depth scores for {len(depth_scores_data)} frames")
    # except FileNotFoundError:
    #     print(f"❌ Depth scores file not found: {depth_scores_path}")
    #     return
    # except json.JSONDecodeError:
    #     print(f"❌ Invalid JSON in depth scores file: {depth_scores_path}")
    #     return
    
    print(f"📹 Processing {min_frames} frames")
    print(f"🔑 Keyframe interval: {keyframe_interval} frames")
    print(f"🗺️ Planning mode: {planning_mode}")
    print(f"⚖️ Score weights - Traversability: {traversability_weight}, Depth: {depth_weight}")
    
    # Create output directories
    os.makedirs(output_costmap_dir, exist_ok=True)
    os.makedirs(output_overlay_dir, exist_ok=True)
    
    # Storage for current region scores
    current_region_scores = None
    
    # Process each frame
    for frame_idx, (orig_path, seg_path) in enumerate(zip(original_frames, segmented_frames)):
        print(f"\n🔄 Processing frame {frame_idx}/{min_frames}")
        
        # Load frames
        original_img = Image.open(orig_path)
        segmented_img = Image.open(seg_path)
        
        # Ensure same size
        if original_img.size != segmented_img.size:
            # print(f"Not same size: {original_img.size},{segmented_img.size}")
            original_img = original_img.resize(segmented_img.size, Image.Resampling.LANCZOS)
            # print(f"same size: {original_img.size},{segmented_img.size}")
        # Extract masks from NPZ file for this frame
        chunk_idx = frame_idx // keyframe_interval
        frame_idx_in_chunk = frame_idx % keyframe_interval
        
        # Build NPZ path
        folder_name = f"output_rpl_staircase_chunk_{chunk_idx}_npz"
        npz_name = f"output_rpl_staircase_frame_{frame_idx_in_chunk:04d}_masks.npz"
        npz_path = os.path.join(npz_base_dir, folder_name, npz_name)
        
        # Load masks from NPZ
        masks_dict = {}
        if os.path.exists(npz_path):
            mask_data = np.load(npz_path)
            for key in mask_data.files:
                mask = mask_data[key].astype(bool)  # Extract the mask
                region_id = f"Region {key}"
                # print(f"region_id : {region_id}")
                masks_dict[region_id] = mask
            print(f"✅ Loaded {len(masks_dict)} masks from {npz_path}")
        else:
            print(f"❌ NPZ file not found: {npz_path}")
            continue
        
        # Check if this is a keyframe
        if frame_idx % keyframe_interval == 0:
            print(f"🎯 Keyframe detected - Querying VLM...")
            
            region_scores = query_gemini_with_premade_masks(original_img, segmented_img, client) 
            
            if region_scores:
                current_region_scores = region_scores
                print(f"✅ Updated region scores for {len(region_scores)} regions")
            else:
                print("❌ VLM query failed, using previous scores")
        
        # If we have region scores and masks, create costmap and plan path
        if current_region_scores and masks_dict:
            # Get depth scores for current frame
            # frame_depth_scores = depth_scores_data.get(str(frame_idx), {})
            # print(f"📐 Depth scores available for {len(frame_depth_scores)} regions in frame {frame_idx}")
            
            # Combine traversability and depth scores
            # combined_region_scores = combine_traversability_depth_scores(
            #     current_region_scores, frame_depth_scores, 
            #     traversability_weight, depth_weight
            # )
            
            # Create costmap using MASKS (more accurate than color-based)
            costmap = create_costmap_from_mask_and_scores(masks_dict, current_region_scores)

            # Plan path based on mode
            start_point = (costmap.shape[0] - 3, costmap.shape[1]//2 )  # Bottom left
            goal_point = (costmap.shape[0] // 4, costmap.shape[1] // 2)
            
            if planning_mode == 'goal' and goal_point:
                path, success, planning_type = unified_a_star_planning(
                    costmap, start_point, goal=goal_point
                )
                planning_info = f"Goal: {goal_point}"
            else:
                path, success, planning_type = unified_a_star_planning(
                    costmap, start_point, horizon_distance=horizon_distance
                )
                planning_info = f"Horizon: {horizon_distance}"
            
            print(f"Path planning: {success}, {len(path) if path else 0} steps")
            
            # Create both visualizations
            costmap_frame = create_costmap_frame(costmap, path, start_point, planning_type, planning_info, frame_idx)
            overlay_frame = create_overlay_frame(original_img, path, start_point, planning_type, goal_point, frame_idx)
            
            # Save both frames
            costmap_path = os.path.join(output_costmap_dir, f"frame_{frame_idx:06d}.png")
            overlay_path = os.path.join(output_overlay_dir, f"frame_{frame_idx:06d}.png")
            
            cv2.imwrite(costmap_path, cv2.cvtColor(costmap_frame, cv2.COLOR_RGB2BGR))
            cv2.imwrite(overlay_path, cv2.cvtColor(overlay_frame, cv2.COLOR_RGB2BGR))
            
            print(f"💾 Saved: {costmap_path}")
            print(f"💾 Saved: {overlay_path}")   
        else:
            print("❌ No region scores or masks available for this frame")
    
    print("🎬 Video processing completed!")
    print("📹 Use these commands to create videos:")
    print(f"ffmpeg -framerate 30 -i {output_costmap_dir}/frame_%06d.png -c:v libx264 -pix_fmt yuv420p costmap_video.mp4")
    print(f"ffmpeg -framerate 30 -i {output_overlay_dir}/frame_%06d.png -c:v libx264 -pix_fmt yuv420p overlay_video.mp4")

# %%
def combine_traversability_depth_scores(traversability_scores, depth_scores, 
                                      traversability_weight=0.7, depth_weight=0.3):

    combined_scores = {}
    
    print(f"🔧 Combining scores - T_weight: {traversability_weight}, D_weight: {depth_weight}")
    
    for region_id, t_scores in traversability_scores.items():
        # Extract region number from "Region X" format
        region_num = region_id.replace('Region ', '')
        
        # Get traversability score (0-1, higher = better)
        traversability_score = t_scores['traversability']
        
        # Get depth value for this region
        if region_num in depth_scores:
            depth_value = depth_scores[region_num]
            # Use depth value directly (assuming it's already in a usable range)
            depth_score = depth_value
        else:
            # If no depth data, use neutral score
            depth_score = 0
            print(f"  ⚠️  No depth data for {region_id}, using default depth score 0.5")
        
        # Combine scores using weighted average
        combined_score = (traversability_score * traversability_weight + 
                         depth_score * depth_weight)
        
        # Store ONLY the combined score
        combined_scores[region_id] = {
            'combined_score': combined_score  # This is what will be used for costmap
        }
        
        print(f"  📊 {region_id}: T={traversability_score:.3f}, D={depth_score:.3f}, Combined={combined_score:.3f}")
    
    return combined_scores

# %%
def create_costmap_frame(costmap, path, start, planning_type, planning_info, frame_idx):
    """Create costmap visualization at original pixel size"""
    
    # Convert costmap to color image (viridis colormap)
    costmap_normalized = (costmap * 255).astype(np.uint8)
    costmap_color = cv2.applyColorMap(costmap_normalized, cv2.COLORMAP_VIRIDIS)
    
    # Convert to RGB for consistency
    costmap_rgb = cv2.cvtColor(costmap_color, cv2.COLOR_BGR2RGB)
    
    if path:
        # Draw path lines (path is in pixel coordinates)
        path_points = [(int(x), int(y)) for y, x in path]  # Swap to (x, y)
        
        for i in range(len(path_points) - 1):
            cv2.line(costmap_rgb, path_points[i], path_points[i+1], (255, 0, 0), 2)
        
        # for point in path_points:
        #     cv2.circle(costmap_rgb, point, 2, (255, 255, 255), -1)
    
    # Draw start point
    start_point = (int(start[1]), int(start[0]))
    cv2.circle(costmap_rgb, start_point, 4, (0, 255, 0), -1)
    
    # Draw goal if exists
    if planning_type == 'goal' and path:
        goal_point = (int(path[-1][1]), int(path[-1][0]))
        cv2.circle(costmap_rgb, goal_point, 4, (0, 0, 255), -1)
    
    return costmap_rgb

def create_overlay_frame(original_image, path, start, planning_type, goal_point, frame_idx):
    """Create overlay frame for pixel-level planning (no grid conversion)"""
    # Convert to numpy if needed
    if isinstance(original_image, Image.Image):
        original_np = np.array(original_image)
    else:
        original_np = original_image
    
    # Create a copy to draw on
    overlay = original_np.copy()
    
    if path:
        # Path is already in PIXEL coordinates - no conversion needed!
        # Note: path coordinates are (y, x) but OpenCV uses (x, y)
        path_points = [(int(x), int(y)) for y, x in path]  # Swap to (x, y) for OpenCV
        
        # Draw path lines
        for i in range(len(path_points) - 1):
            cv2.line(overlay, path_points[i], path_points[i+1], (255, 0, 0), 3)  # Red line
        
        # Draw path points
        # for point in path_points:
        #     cv2.circle(overlay, point, 4, (255, 255, 255), -1)  # White points
        #     cv2.circle(overlay, point, 4, (255, 0, 0), 2)  # Red border
    
    # Draw start point (already in pixel coordinates)
    start_point = (int(start[1]), int(start[0]))  # Swap to (x, y)
    cv2.circle(overlay, start_point, 10, (0, 255, 0), -1)  # Green start
    
    # Draw goal if exists
    if planning_type == 'goal' and goal_point:
        goal_point_px = (int(goal_point[1]), int(goal_point[0]))  # Swap to (x, y)
        cv2.circle(overlay, goal_point_px, 10, (0, 0, 255), -1)  # Red goal
    
    # Add text
    text = f"Frame {frame_idx} - {planning_type}"
    cv2.putText(overlay, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    return overlay

# %%
# Usage example:
def main():
    # Define your directories
    original_frames_dir = "rpl_staircase_original_frames"
    segmented_frames_dir = "rpl_staircase_masked_frames" 
    output_costmap_dir = "path/to/output_costmap_frames"
    output_overlay_dir = "path/to/output_overlay_frames"
    
    # Your Gemini client
    # --- PASTE YOUR API KEY HERE ---
    YOUR_API_KEY = "AIzaSyAE5QdmsjEmElEvXBg_aCu7tOws6IhNyWY" 

    # Set the environment variable for the current session
    os.environ['GEMINI_API_KEY'] = YOUR_API_KEY

    # Initialize the client. It will automatically use the environment variable.
    try:
        client = genai.Client()
        print("✅ Gemini Client Initialized Successfully.")
    except Exception as e:
        print(f"❌ Error initializing Gemini Client. Check your API key: {e}")
    
    # # Load color mapping at the start
    # with open('color_dict_chunk.json', 'r') as f:
    #     color_mapping_data = json.load(f)

    # # Convert to your color_to_region format
    # color_to_region = {}
    # for region_id, color_list in color_mapping_data.items():
    #     color_tuple = tuple(color_list)  # Convert [197, 111, 218] to (197, 111, 218)
    #     color_to_region[color_tuple] = f"Region {region_id}"

    # print(f"🎨 Loaded color mapping for {len(color_to_region)} regions")

    # Choose planning mode
    planning_mode = 'horizon'  # or 'goal'

    
    # Process all frames
    process_video_frames(
        original_frames_dir=original_frames_dir,
        segmented_frames_dir=segmented_frames_dir,
        npz_base_dir = "output_rpl_staircase",
        output_costmap_dir=output_costmap_dir,
        output_overlay_dir=output_overlay_dir,
        client=client,
        depth_scores_path = "traversability_scores.json",
        keyframe_interval=50,
        horizon_distance=100,
        planning_mode=planning_mode,
        traversability_weight=0.7, 
        depth_weight=0.3
    )

# %%
# if __name__ == "__main__":
main()
# Out:
# ✅ Gemini Client Initialized Successfully.
# 📹 Processing 681 frames
# 🔑 Keyframe interval: 50 frames
# 🗺️ Planning mode: horizon
# ⚖️ Score weights - Traversability: 0.7, Depth: 0.3
#
# 🔄 Processing frame 0/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0000_masks.npz
# 🎯 Keyframe detected - Querying VLM...
# Sending request to model: gemini-flash-lite-latest...
#
# ✅ API Call Completed.
# ⏱️ Time Taken: 1.36 seconds
# ----------------------------------------
#
#
# --- Raw Gemini Output ---
# Region 0: 0.0, 0.95, Stairs/steps, not traversable
# Region 1: 0.0, 0.95, Stairs/steps, not traversable
# Region 2: 0.3, 0.85, Stairs/steps, low traversability
# Region 3: 0.0, 0.95, Stairs/steps, not traversable
# Region 4: 0.0, 0.95, Stairs/steps, not traversable
# Region 5: 0.7, 0.9, Flat ground/pavement, good traversability
# Region 6: 0.0, 0.95, Stairs/steps, not traversable
# Region 7: 0.0, 0.95, Stairs/steps, not traversable
# Region 8: 0.6, 0.9, Sloped ramp, moderate traversability
# Region 9: 0.0, 0.95, Stairs/steps, not traversable
# Region 10: 0.0, 0.95, Stairs/steps, not traversable
# Region 11: 0.0, 0.95, Stairs/steps, not traversable
# Region 12: 0.0, 0.95, Stairs/steps, not traversable
# Region 13: 0.0, 0.95, Stairs/steps, not traversable
# Region 14: 0.0, 0.95, Stairs/steps, not traversable
# Region 15: 0.0, 0.95, Stairs/steps, not traversable
# Region 16: 0.0, 0.95, Stairs/steps, not traversable
# Region 17: 0.0, 0.95, Stairs/steps, not traversable
# Region 18: 0.0, 0.95, Stairs/steps, not traversable
# Region 19: 0.0, 0.95, Stairs/steps, not traversable
# -------------------------
#
# ✅ Parsed: Region 0 -> T=0.00, C=0.95
# ✅ Parsed: Region 1 -> T=0.00, C=0.95
# ✅ Parsed: Region 2 -> T=0.30, C=0.85
# ✅ Parsed: Region 3 -> T=0.00, C=0.95
# ✅ Parsed: Region 4 -> T=0.00, C=0.95
# ✅ Parsed: Region 5 -> T=0.70, C=0.90
# ✅ Parsed: Region 6 -> T=0.00, C=0.95
# ✅ Parsed: Region 7 -> T=0.00, C=0.95
# ✅ Parsed: Region 8 -> T=0.60, C=0.90
# ✅ Parsed: Region 9 -> T=0.00, C=0.95
# ✅ Parsed: Region 10 -> T=0.00, C=0.95
# ✅ Parsed: Region 11 -> T=0.00, C=0.95
# ✅ Parsed: Region 12 -> T=0.00, C=0.95
# ✅ Parsed: Region 13 -> T=0.00, C=0.95
# ✅ Parsed: Region 14 -> T=0.00, C=0.95
# ✅ Parsed: Region 15 -> T=0.00, C=0.95
# ✅ Parsed: Region 16 -> T=0.00, C=0.95
# ✅ Parsed: Region 17 -> T=0.00, C=0.95
# ✅ Parsed: Region 18 -> T=0.00, C=0.95
# ✅ Parsed: Region 19 -> T=0.00, C=0.95
# --- Successfully Parsed Scores ---
# Region 0: Traversability=0.00, Confidence=0.95
# Region 1: Traversability=0.00, Confidence=0.95
# Region 2: Traversability=0.30, Confidence=0.85
# Region 3: Traversability=0.00, Confidence=0.95
# Region 4: Traversability=0.00, Confidence=0.95
# Region 5: Traversability=0.70, Confidence=0.90
# Region 6: Traversability=0.00, Confidence=0.95
# Region 7: Traversability=0.00, Confidence=0.95
# Region 8: Traversability=0.60, Confidence=0.90
# Region 9: Traversability=0.00, Confidence=0.95
# Region 10: Traversability=0.00, Confidence=0.95
# Region 11: Traversability=0.00, Confidence=0.95
# Region 12: Traversability=0.00, Confidence=0.95
# Region 13: Traversability=0.00, Confidence=0.95
# Region 14: Traversability=0.00, Confidence=0.95
# Region 15: Traversability=0.00, Confidence=0.95
# Region 16: Traversability=0.00, Confidence=0.95
# Region 17: Traversability=0.00, Confidence=0.95
# Region 18: Traversability=0.00, Confidence=0.95
# Region 19: Traversability=0.00, Confidence=0.95
# ✅ Updated region scores for 20 regions
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5424 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40249 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=1570 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=669 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=16931 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10834 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=8995 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7761 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4479 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4833 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4791 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4478 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3447 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3124 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2306 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1478 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1133 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1132 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=370 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=134 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000000.png
# 💾 Saved: path/to/output_overlay_frames/frame_000000.png
#
# 🔄 Processing frame 1/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0001_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5218 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40467 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=1741 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=513 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17061 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10858 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9026 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7730 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4496 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4875 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4829 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4488 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3455 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3072 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2344 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1493 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1143 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1142 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=381 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=144 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000001.png
# 💾 Saved: path/to/output_overlay_frames/frame_000001.png
#
# 🔄 Processing frame 2/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0002_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5048 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40565 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=1201 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=493 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17056 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10892 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9013 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7743 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4495 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4878 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4836 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4500 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3443 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3072 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2350 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1493 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1144 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1140 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=380 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=147 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000002.png
# 💾 Saved: path/to/output_overlay_frames/frame_000002.png
#
# 🔄 Processing frame 3/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0003_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5131 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40622 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=894 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=525 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17074 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10876 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=8998 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7741 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4479 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4860 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4841 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4506 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3471 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3073 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2360 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1504 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1154 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1135 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=377 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=151 pixels
# Path planning: True, 196 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000003.png
# 💾 Saved: path/to/output_overlay_frames/frame_000003.png
#
# 🔄 Processing frame 4/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0004_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5225 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40680 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=879 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=516 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17136 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10887 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9005 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7707 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4494 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4852 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4847 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4494 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3467 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3096 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2340 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1499 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1151 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1144 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=372 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=148 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000004.png
# 💾 Saved: path/to/output_overlay_frames/frame_000004.png
#
# 🔄 Processing frame 5/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0005_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5364 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40690 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=850 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=501 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17125 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10954 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=8989 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7670 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4504 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4863 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4850 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4487 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3438 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3099 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2346 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1490 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1154 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1128 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=365 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=157 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000005.png
# 💾 Saved: path/to/output_overlay_frames/frame_000005.png
#
# 🔄 Processing frame 6/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0006_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5451 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40931 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=857 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=461 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10935 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17171 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=8978 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7677 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4904 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4769 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4589 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4505 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3451 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3082 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2321 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1495 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1162 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1148 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=369 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=155 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000006.png
# 💾 Saved: path/to/output_overlay_frames/frame_000006.png
#
# 🔄 Processing frame 7/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0007_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5611 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40975 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=804 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=419 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10981 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17213 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=8994 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7640 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4929 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4794 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4567 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4544 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3455 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3081 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2271 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1502 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1158 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1105 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=370 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=149 pixels
# Path planning: True, 195 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000007.png
# 💾 Saved: path/to/output_overlay_frames/frame_000007.png
#
# 🔄 Processing frame 8/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0008_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5570 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=40991 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=799 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=427 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11013 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17257 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9023 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7593 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4943 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4833 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4559 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4521 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3448 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3089 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2257 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1507 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1162 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1142 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=363 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=157 pixels
# Path planning: True, 195 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000008.png
# 💾 Saved: path/to/output_overlay_frames/frame_000008.png
#
# 🔄 Processing frame 9/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0009_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5563 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=41177 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=661 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=392 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10473 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17341 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9058 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=8143 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4937 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4925 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4589 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4502 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3457 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=3051 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2325 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1506 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1178 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1138 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=365 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=151 pixels
# Path planning: True, 182 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000009.png
# 💾 Saved: path/to/output_overlay_frames/frame_000009.png
#
# 🔄 Processing frame 10/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0010_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5542 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=41349 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=677 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=429 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10412 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17317 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9056 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=8138 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4970 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4933 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4607 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4525 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3457 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2984 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2282 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1525 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1158 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1139 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=364 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=149 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000010.png
# 💾 Saved: path/to/output_overlay_frames/frame_000010.png
#
# 🔄 Processing frame 11/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0011_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5636 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=41649 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=650 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=475 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17386 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10310 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9068 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=8099 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=4975 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4961 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4597 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4531 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3442 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2962 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2279 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1527 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1167 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1124 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=369 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=148 pixels
# Path planning: True, 195 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000011.png
# 💾 Saved: path/to/output_overlay_frames/frame_000011.png
#
# 🔄 Processing frame 12/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0012_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5559 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=42268 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=588 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=418 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17380 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10490 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9060 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=7686 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5043 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5007 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4579 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4573 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3464 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2974 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2329 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1495 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1202 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1055 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=380 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=136 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000012.png
# 💾 Saved: path/to/output_overlay_frames/frame_000012.png
#
# 🔄 Processing frame 13/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0013_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=5150 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=42858 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=611 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=395 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17589 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11051 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9089 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6728 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5138 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5062 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4625 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4610 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3489 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2850 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2365 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1542 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1189 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1068 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=367 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=123 pixels
# Path planning: True, 180 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000013.png
# 💾 Saved: path/to/output_overlay_frames/frame_000013.png
#
# 🔄 Processing frame 14/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0014_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4974 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=43797 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=461 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=375 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17690 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11078 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9142 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6254 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4668 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5193 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5160 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4609 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3535 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2703 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2389 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1558 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1207 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1042 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=395 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=111 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000014.png
# 💾 Saved: path/to/output_overlay_frames/frame_000014.png
#
# 🔄 Processing frame 15/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0015_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4609 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=44233 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=421 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=438 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=17837 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10517 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9225 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6741 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5217 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5178 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4740 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4592 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3552 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2556 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2412 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1576 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1226 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=1011 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=380 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=102 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000015.png
# 💾 Saved: path/to/output_overlay_frames/frame_000015.png
#
# 🔄 Processing frame 16/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0016_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4293 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=44189 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=303 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=438 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18119 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10593 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9347 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6734 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5301 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5245 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4794 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4597 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3540 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2504 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2426 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1603 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1244 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=979 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=387 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=102 pixels
# Path planning: True, 179 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000016.png
# 💾 Saved: path/to/output_overlay_frames/frame_000016.png
#
# 🔄 Processing frame 17/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0017_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4824 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=43100 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=163 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=350 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18235 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10649 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9452 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6944 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5369 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=4854 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5294 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4669 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3587 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2652 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2451 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1599 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1262 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=985 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=387 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=103 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000017.png
# 💾 Saved: path/to/output_overlay_frames/frame_000017.png
#
# 🔄 Processing frame 18/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0018_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4380 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=42335 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=460 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=374 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18364 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11385 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9562 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6228 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5417 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5389 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4854 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4648 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3595 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2678 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2482 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1631 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1259 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=923 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=398 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=112 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000018.png
# 💾 Saved: path/to/output_overlay_frames/frame_000018.png
#
# 🔄 Processing frame 19/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0019_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=4534 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=42215 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=234 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=455 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18592 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10736 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9659 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6968 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5526 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5443 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4919 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4698 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3590 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2610 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2522 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1662 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1272 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=849 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=397 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=103 pixels
# Path planning: True, 197 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000019.png
# 💾 Saved: path/to/output_overlay_frames/frame_000019.png
#
# 🔄 Processing frame 20/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0020_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=3984 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=42760 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=404 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=498 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18762 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=10865 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9729 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=6424 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5557 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5542 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=4993 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4713 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3651 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2543 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2442 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1643 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1299 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=782 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=409 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=88 pixels
# Path planning: True, 179 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000020.png
# 💾 Saved: path/to/output_overlay_frames/frame_000020.png
#
# 🔄 Processing frame 21/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0021_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=3078 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=43677 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=1369 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=539 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18956 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11412 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9768 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=5906 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5694 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5625 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5081 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4809 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3712 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2546 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=2135 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1644 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1373 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=729 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=415 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=79 pixels
# Path planning: True, 198 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000021.png
# 💾 Saved: path/to/output_overlay_frames/frame_000021.png
#
# 🔄 Processing frame 22/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0022_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=3822 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=45029 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=249 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=541 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18977 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11384 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9789 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5843 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5811 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=5307 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5140 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=4906 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3843 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2544 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=1834 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1439 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=1186 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=553 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=378 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=60 pixels
# Path planning: True, 199 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000022.png
# 💾 Saved: path/to/output_overlay_frames/frame_000022.png
#
# 🔄 Processing frame 23/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0023_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=1798 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=45890 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=1958 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=526 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18853 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11708 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9795 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=5998 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5982 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5262 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=5082 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=4900 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=3907 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2564 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=1614 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1307 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=893 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=353 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=342 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=42 pixels
# Path planning: True, 175 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000023.png
# 💾 Saved: path/to/output_overlay_frames/frame_000023.png
#
# 🔄 Processing frame 24/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0024_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=3428 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=46368 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=130 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=516 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18821 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=11882 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9843 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=6065 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=6005 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5352 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=5209 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=4595 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=4060 pixels
#   🎯 Region 7: traversability=0.000, base_cost=1.000, area=2578 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=1468 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1234 pixels
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=730 pixels
#   🎯 Region 14: traversability=0.000, base_cost=1.000, area=327 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=200 pixels
#   🎯 Region 0: traversability=0.000, base_cost=1.000, area=26 pixels
# Path planning: True, 195 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000024.png
# 💾 Saved: path/to/output_overlay_frames/frame_000024.png
#
# 🔄 Processing frame 25/681
# ✅ Loaded 20 masks from output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0025_masks.npz
# 📊 Processing 20 masks for gradient-based costmap
#   🎯 Region 13: traversability=0.000, base_cost=1.000, area=1567 pixels
#   🎯 Region 5: traversability=0.700, base_cost=0.300, area=46803 pixels
#   🎯 Region 1: traversability=0.000, base_cost=1.000, area=2239 pixels
#   🎯 Region 10: traversability=0.000, base_cost=1.000, area=544 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=18659 pixels
#   🎯 Region 2: traversability=0.300, base_cost=0.700, area=12247 pixels
#   🎯 Region 8: traversability=0.600, base_cost=0.400, area=9893 pixels
#   🎯 Region 16: traversability=0.000, base_cost=1.000, area=6143 pixels
#   🎯 Region 17: traversability=0.000, base_cost=1.000, area=5764 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=5412 pixels
#   🎯 Region 4: traversability=0.000, base_cost=1.000, area=5396 pixels
#   🎯 Region 6: traversability=0.000, base_cost=1.000, area=4390 pixels
# ...
# 💾 Saved: path/to/output_overlay_frames/frame_000670.png
#
# 🔄 Processing frame 671/681
# ✅ Loaded 19 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0021_masks.npz
# 📊 Processing 19 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=7511 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=280 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=62365 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1139 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=16118 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=13725 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=72 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4337 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4967 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3312 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=2877 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1508 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1481 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1470 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1247 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=484 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=415 pixels
#   🎯 Region 25: traversability=0.000, base_cost=1.000, area=34 pixels
#   🎯 Region 12: traversability=0.000, base_cost=1.000, area=23 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000671.png
# 💾 Saved: path/to/output_overlay_frames/frame_000671.png
#
# 🔄 Processing frame 672/681
# ✅ Loaded 18 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0022_masks.npz
# 📊 Processing 18 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=7669 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=279 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=61892 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1140 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=16462 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=13920 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=51 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4364 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4672 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3354 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=2976 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1542 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1517 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1480 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1257 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=493 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=409 pixels
#   🎯 Region 25: traversability=0.000, base_cost=1.000, area=12 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000672.png
# 💾 Saved: path/to/output_overlay_frames/frame_000672.png
#
# 🔄 Processing frame 673/681
# ✅ Loaded 18 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0023_masks.npz
# 📊 Processing 18 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=7920 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=191 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=60982 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1143 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=16718 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=14360 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=73 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4356 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4729 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3350 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=2942 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1572 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1521 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1468 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1245 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=497 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=409 pixels
#   🎯 Region 25: traversability=0.000, base_cost=1.000, area=4 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000673.png
# 💾 Saved: path/to/output_overlay_frames/frame_000673.png
#
# 🔄 Processing frame 674/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0024_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8143 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=42 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=60143 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1248 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=16966 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=14723 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=93 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4319 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4730 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3339 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3064 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1511 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1500 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1441 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1287 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=508 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=446 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000674.png
# 💾 Saved: path/to/output_overlay_frames/frame_000674.png
#
# 🔄 Processing frame 675/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0025_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8339 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=193 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=58959 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1133 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17287 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=15246 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=54 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4330 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4697 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3378 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3084 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1559 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1479 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1466 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1273 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=510 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=450 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000675.png
# 💾 Saved: path/to/output_overlay_frames/frame_000675.png
#
# 🔄 Processing frame 676/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0026_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8470 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=184 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=58202 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1224 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17438 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=15635 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=78 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4290 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4592 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3352 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3088 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1574 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1521 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1418 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1302 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=492 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=473 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000676.png
# 💾 Saved: path/to/output_overlay_frames/frame_000676.png
#
# 🔄 Processing frame 677/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0027_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8567 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=165 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=57513 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1219 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17538 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=16069 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=140 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4071 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4654 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3377 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3210 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1567 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1504 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1413 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1306 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=521 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=469 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000677.png
# 💾 Saved: path/to/output_overlay_frames/frame_000677.png
#
# 🔄 Processing frame 678/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0028_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8661 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=120 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=56708 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1165 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17732 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=16461 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=54 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4271 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=4777 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3419 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3032 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1596 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1534 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1413 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1325 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=495 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=486 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000678.png
# 💾 Saved: path/to/output_overlay_frames/frame_000678.png
#
# 🔄 Processing frame 679/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0029_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=8817 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=355 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=55681 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1224 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17722 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=16701 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=143 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=5017 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=4030 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3402 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3192 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1604 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1514 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1449 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1331 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=514 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=460 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000679.png
# 💾 Saved: path/to/output_overlay_frames/frame_000679.png
#
# 🔄 Processing frame 680/681
# ✅ Loaded 17 masks from output_rpl_staircase/output_rpl_staircase_chunk_13_npz/output_rpl_staircase_frame_0030_masks.npz
# 📊 Processing 17 masks for gradient-based costmap
#   🎯 Region 18: traversability=0.000, base_cost=1.000, area=9042 pixels
#   🎯 Region 9: traversability=0.000, base_cost=1.000, area=325 pixels
#   🎯 Region 3: traversability=0.000, base_cost=1.000, area=54715 pixels
#   🎯 Region 8: traversability=0.000, base_cost=1.000, area=1185 pixels
#   🎯 Region 2: traversability=0.000, base_cost=1.000, area=17965 pixels
#   🎯 Region 19: traversability=0.000, base_cost=1.000, area=16987 pixels
#   🎯 Region 11: traversability=0.000, base_cost=1.000, area=149 pixels
#   🎯 Region 0: traversability=0.400, base_cost=0.600, area=5085 pixels
#   🎯 Region 1: traversability=0.400, base_cost=0.600, area=3979 pixels
#   🎯 Region 6: traversability=0.400, base_cost=0.600, area=3431 pixels
#   🎯 Region 20: traversability=0.000, base_cost=1.000, area=3196 pixels
#   🎯 Region 7: traversability=0.400, base_cost=0.600, area=1615 pixels
#   🎯 Region 21: traversability=0.000, base_cost=1.000, area=1557 pixels
#   🎯 Region 17: traversability=0.500, base_cost=0.500, area=1444 pixels
#   🎯 Region 15: traversability=0.000, base_cost=1.000, area=1367 pixels
#   🎯 Region 24: traversability=0.000, base_cost=1.000, area=517 pixels
#   🎯 Region 14: traversability=0.400, base_cost=0.600, area=475 pixels
# Path planning: False, 0 steps
# 💾 Saved: path/to/output_costmap_frames/frame_000680.png
# 💾 Saved: path/to/output_overlay_frames/frame_000680.png
# 🎬 Video processing completed!
# 📹 Use these commands to create videos:
# ffmpeg -framerate 30 -i path/to/output_costmap_frames/frame_%06d.png -c:v libx264 -pix_fmt yuv420p costmap_video.mp4
# ffmpeg -framerate 30 -i path/to/output_overlay_frames/frame_%06d.png -c:v libx264 -pix_fmt yuv420p overlay_video.mp4

# %%
import os

# Get the current directory where your notebook is running
current_dir = os.getcwd()
print(f"📁 Current working directory: {current_dir}")

# Use absolute path
npz_folder = os.path.join(current_dir, "output_rpl_staircase", "output_rpl_staircase_chunk_0_npz")
npz_path = os.path.join(npz_folder, "output_rpl_staircase_frame_0000_masks.npz")

print(f"🔍 Looking for: {npz_path}")
print(f"📄 File exists: {os.path.exists(npz_path)}")
# Out:
# 📁 Current working directory: /home/jovyan/eai2025_lab2_perception
# 🔍 Looking for: /home/jovyan/eai2025_lab2_perception/output_rpl_staircase/output_rpl_staircase_chunk_0_npz/output_rpl_staircase_frame_0000_masks.npz
# 📄 File exists: True
