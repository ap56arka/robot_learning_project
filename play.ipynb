# %% [markdown]
# ## Install DepthAnything

# %%
# !git clone https://github.com/LiheYoung/Depth-Anything.git
# Out:
# Cloning into 'Depth-Anything'...
# remote: Enumerating objects: 441, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 441 (delta 115), reused 41 (delta 41), pack-reused 283 (from 2)
# Receiving objects: 100% (441/441), 237.90 MiB | 41.74 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# !ls
# Out:
# app.py	    depth_anything  metric_depth      run.py	    torchhub
# assets	    gallery.md	    README.md	      run_video.py
# controlnet  LICENSE	    requirements.txt  semseg

# %%
# %cd Depth-Anything
# Out:
# [Errno 2] No such file or directory: 'Depth-Anything'
# /home/jovyan/project_dir/Depth-Anything
# /home/jovyan/project/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 118.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl (888.0 MB)
# ...
#   Using cached torchvision-0.23.0-cp310-cp310-manylinux_2_28_x86_64.whl (8.6 MB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.4/563.4 kB 132.1 MB/s eta 0:00:00
# ...
#   Using cached pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 175.6 MB/s eta 0:00:00
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 167.5 MB/s eta 0:00:00
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...

# %%
# !git clone https://github.com/ap56arka/robot_learning_project.git
# Out:
# Cloning into 'robot_learning_project'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), 130.52 KiB | 4.83 MiB/s, done.

# %%
# !ls
# Out:
# app.py	    depth_anything  metric_depth      robot_learning_project  semseg
# assets	    gallery.md	    README.md	      run.py		      torchhub
# controlnet  LICENSE	    requirements.txt  run_video.py
